# %%
from ligavision.types import Image
import os
project_root = os.environ.get("ROOTDIR")
test_image = Image(f"{project_root}/video/test/resources/test_image.jpg")
test_image
# Out:
# Image(uri=/home/da/github/liga-ai/liga-vision/video/test/resources/test_image.jpg)
