# %%
from ligavision.types import Image
import os
project_root = os.environ.get("ROOTDIR")
image = Image(f"{project_root}/video/test/resources/test_image.jpg")
image * (0.3, 0.3)
# Out:
# Image(<embedded>)
